# %% [markdown]
# # Python Script for Showing tweets from JSON file in Tabluar Form

# %%
import numpy as np                                                    
import pandas as pd                                                   
import json

# %% [markdown]
# Function for opening json file

# %%
def json_input(location):
    with open(location) as json_file:  
        data = json.load(json_file)
        return data

# %%
data = json_input("tweets.json")
print(data)
# Out:
# [{'Tweets': 'Clarification: Our earlier post which indicates that the interview has been done is referring to the interviews of… https://t.co/x8Etf6qEOn',
#   'Len': 139,
#   'Date Time': '2019-04-10 09:01:29',
#   'Likes': 0,
#   'Retweets': 0},
#  {'Tweets': 'RT @IIITDelhi: Applications open for MTech (CB) through JNU CEEB Admission process. Candidates can check the JNU CEEB admission process in…',
#   'Len': 139,
#   'Date Time': '2019-04-10 04:51:26',
#   'Likes': 0,
#   'Retweets': 1},
#  {'Tweets': 'RT @IIITDelhi: We are delighted to share that IIIT-Delhi is ranked 55 by NIRF this year. We have moved up by 11 positions compared to the p…',
#   'Len': 140,
#   'Date Time': '2019-04-09 16:45:07',
#   'Likes': 0,
#   'Retweets': 14},
#  {'Tweets': 'RT @Harvard: Professor Jelani Nelson founded AddisCoder, a program that teaches students in Ethiopia how to code https://t.co/0sM06p4qxw',
#   'Len': 136,
#   'Date Time': '2019-04-09 05:04:27',
#   'Likes': 0,
#   'Retweets': 35},
#  {'Tweets': 'RT @emnlp2019: For anyone interested in submitting to EMNLP 2019, the anonymity period begins in less two weeks, on April 21.\nhttps://t.co/…',
#   'Len': 140,
#   'Date Time': '2019-04-09 05:04:11',
#   'Likes': 0,
#   'Retweets': 17},
#  {'Tweets': 'RT @multimediaeval: Announcing the 2019 MediaEval multimedia tasks: https://t.co/V6NMt1vaNV Participation is open for anyone who is interes…',
#   'Len': 140,
#   'Date Time': '2019-04-08 19:38:09',
#   'Likes': 0,
#   'Retweets': 15},
#  {'Tweets': 'Many Congratulations to @midasIIITD student, Shagun Uppal @shagunuppls, on getting selected for the summer internsh… https://t.co/bzhiSm4zuB',
#   'Len': 140,
#   'Date Time': '2019-04-08 07:08:12',
#   'Likes': 18,
#   'Retweets': 2},
#  {'Tweets': '@midasIIITD thanks all students who have appeared for the interview yesterday. We will announce the interview resul… https://t.co/qxESgZPtKJ',
#   'Len': 140,
#   'Date Time': '2019-04-08 03:27:42',
#   'Likes': 5,
#   'Retweets': 0},
#  {'Tweets': '@himanchalchandr Meanwhile, complete CV/NLP task first.',
#   'Len': 55,
#   'Date Time': '2019-04-07 14:17:29',
#   'Likes': 0,
#   'Retweets': 0},
#  {'Tweets': '@sayangdipto123 Submit as per the guideline again.',
#   'Len': 50,
#   'Date Time': '2019-04-07 14:17:09',
#   'Likes': 0,
#   'Retweets': 0},
#  {'Tweets': 'We request all students whose interview are scheduled today to join at the time given to them and not before or aft… https://t.co/7cnrlj1b9Q',
#   'Len': 140,
#   'Date Time': '2019-04-07 11:43:24',
#   'Likes': 1,
#   'Retweets': 1},
#  {'Tweets': 'Other queries: "none of the Tweeter Apis give the correct count of favorites tested for most of them, all give the… https://t.co/2jnCTMMqV8',
#   'Len': 139,
#   'Date Time': '2019-04-07 06:55:19',
#   'Likes': 5,
#   'Retweets': 2},
#  {'Tweets': 'Other queries: "do we have to make two different repositories on Github as "Python Problem" and "CV Problem". Or we… https://t.co/45x8RhQcAT',
#   'Len': 140,
#   'Date Time': '2019-04-07 06:53:38',
#   'Likes': 4,
#   'Retweets': 1},
#  {'Tweets': 'Other queries: "If using Twitter api, it does not include any information about images in the response objects sent… https://t.co/JEWZB2XTPq',
#   'Len': 140,
#   'Date Time': '2019-04-07 05:32:27',
#   'Likes': 6,
#   'Retweets': 1},
#  {'Tweets': 'Response to some queries asked by students on @midasIIITD task.\nWhat does the line "dump the responses into JSONlin… https://t.co/Rr6ri8lyVY',
#   'Len': 140,
#   'Date Time': '2019-04-07 05:29:40',
#   'Likes': 7,
#   'Retweets': 1},
#  {'Tweets': 'RT @kdnuggets: Top 8 #Free Must-Read #Books on #DeepLearning #KDN https://t.co/1DtlN91Yjj',
#   'Len': 89,
#   'Date Time': '2019-04-06 17:11:29',
#   'Likes': 0,
#   'Retweets': 2},
#  {'Tweets': '@nupur_baghel @PennDATS Congratulation @nupur_baghel on getting admit from @PennDATS. \nShe got 5/10 acceptance. She… https://t.co/ooD8yneUwS',
#   'Len': 140,
#   'Date Time': '2019-04-06 16:43:27',
#   'Likes': 18,
#   'Retweets': 3},
#  {'Tweets': 'We have emailed the task details to all candidates who have applied to @midasIIITD internship through IIITD portal.… https://t.co/gZwyr7D2Sw',
#   'Len': 140,
#   'Date Time': '2019-04-05 16:08:37',
#   'Likes': 11,
#   'Retweets': 1},
#  {'Tweets': 'RT @rfpvjr: Our NAACL paper on polarization in language on Twitter surrounding mass shootings is up on arXiv! https://t.co/g7wiegXxDg\nThis…',
#   'Len': 139,
#   'Date Time': '2019-04-05 04:05:11',
#   'Likes': 0,
#   'Retweets': 16},
#  {'Tweets': 'RT @kdnuggets: Effective Transfer Learning For NLP https://t.co/Z1m0AzlfVv https://t.co/ccX4Uhxjn8',
#   'Len': 98,
#   'Date Time': '2019-04-05 04:04:43',
#   'Likes': 0,
#   'Retweets': 11},
#  {'Tweets': 'RT @stanfordnlp: What’s new in @Stanford CS224N Natural Language Processing with Deep Learning for 2019? Question answering—1D CNNs—subword…',
#   'Len': 140,
#   'Date Time': '2019-04-03 18:31:53',
#   'Likes': 0,
#   'Retweets': 59},
#  {'Tweets': "RT @DeepMindAI: Today we're releasing a large-scale extendable dataset of mathematical questions, for training (and evaluating the abilitie…",
#   'Len': 140,
#   'Date Time': '2019-04-03 17:04:32',
#   'Likes': 0,
#   'Retweets': 872},
#  {'Tweets': 'RT @ylecun: Congratulations Jitendra Malik !\n\nAwards are raining on FAIRies these days... https://t.co/1WNcSeQLZe',
#   'Len': 113,
#   'Date Time': '2019-04-03 09:03:40',
#   'Likes': 0,
#   'Retweets': 16},
#  {'Tweets': 'RT @IIITDelhi: Another chance to take admission in the Ph.D. program in IIIT Delhi. \nAdmissions open for Ph.D. program mathematics \n\nLog on…',
#   'Len': 140,
#   'Date Time': '2019-04-03 07:46:02',
#   'Likes': 0,
#   'Retweets': 4},
#  {'Tweets': 'Dear @midasIIITD internship candidates who have submitted their solutions to the task, we have sent you an email re… https://t.co/4lCcAmwBKc',
#   'Len': 140,
#   'Date Time': '2019-04-02 04:20:13',
#   'Likes': 8,
#   'Retweets': 1},
#  {'Tweets': 'Looking forward to your paper submission to @IEEEBigMM19. \n\nImportant Dates:\nRegular Paper: 11:59pm PST, May 10, 20… https://t.co/ODYKLC8z0s',
#   'Len': 140,
#   'Date Time': '2019-04-02 02:44:54',
#   'Likes': 5,
#   'Retweets': 1},
#  {'Tweets': 'RT @ngrams: Reproducibility in multimedia research in @sigmm records https://t.co/hOyMxtmy7A Plus reminder to past-year authors: Today 1 Ap…',
#   'Len': 140,
#   'Date Time': '2019-04-02 02:35:44',
#   'Likes': 0,
#   'Retweets': 7},
#  {'Tweets': 'Online application for https://t.co/DJFDrQsHZP. Admission 2019 at @IIITDelhi has been open\n\nLog on to know more and… https://t.co/iqmGyRn1R0',
#   'Len': 140,
#   'Date Time': '2019-04-01 06:53:08',
#   'Likes': 7,
#   'Retweets': 2},
#  {'Tweets': 'RT @ACMMM19: A final reminder of the Reproducibility Track: Authors of 2017 and 2018 papers are invited to submit a short reproducibility p…',
#   'Len': 140,
#   'Date Time': '2019-03-31 10:21:24',
#   'Likes': 0,
#   'Retweets': 10},
#  {'Tweets': 'RT @isarth23: Thanks for the support and help @debanjanbhucs @RatnRajiv and @midasIIITD. It was a great learning experience! Glad to be par…',
#   'Len': 140,
#   'Date Time': '2019-03-29 19:43:24',
#   'Likes': 0,
#   'Retweets': 2},
#  {'Tweets': 'Since SemEval-2019 will be held June 6-7, 2019 in Minneapolis, USA, collocated with NAACL-HLT 2019, it will great s… https://t.co/Jrl1uSesPc',
#   'Len': 140,
#   'Date Time': '2019-03-29 17:16:40',
#   'Likes': 9,
#   'Retweets': 1},
#  {'Tweets': '+@aggarwal_kartik.\nCongrats! Wish you many more success.',
#   'Len': 56,
#   'Date Time': '2019-03-29 17:04:30',
#   'Likes': 2,
#   'Retweets': 0},
#  {'Tweets': 'RT @aggarwal_kartik: Our work (@midasIIITD ) accepted at SemEval 2019 at @NAACLHLT : "MIDAS at SemEval-2019 Task 9: Suggestion Mining from…',
#   'Len': 139,
#   'Date Time': '2019-03-29 17:03:29',
#   'Likes': 0,
#   'Retweets': 1},
#  {'Tweets': 'Congratulations! @midasIIITD team, @isarth23 @LaibaMehnaz @Simcyy @debanjanbhucs @RatnRajiv @the_dhumketu for getti… https://t.co/z8pT3ojhoP',
#   'Len': 140,
#   'Date Time': '2019-03-29 17:02:24',
#   'Likes': 9,
#   'Retweets': 1},
#  {'Tweets': '@EEMLcommunity @radamihalcea too many deadlines coming, @ACMMM19 @IEEEBigMM19 @EEMLcommunity',
#   'Len': 92,
#   'Date Time': '2019-03-29 05:35:22',
#   'Likes': 0,
#   'Retweets': 0},
#  {'Tweets': 'RT @stanfordnlp: CS224N Natural Language Processing with Deep Learning 2019 @Stanford course videos by @chrmanning, @abigail_e_see &amp; guests…',
#   'Len': 144,
#   'Date Time': '2019-03-28 16:55:01',
#   'Likes': 0,
#   'Retweets': 719},
#  {'Tweets': 'RT @ylecun: Learn PyTorch by running on Google GPUs for free. https://t.co/pt038TMnWR',
#   'Len': 85,
#   'Date Time': '2019-03-28 16:54:37',
#   'Likes': 0,
#   'Retweets': 155},
#  {'Tweets': 'Dr. Vineeth N Balasubramanian will present a Talk on "Towards Explainable Deep Learning: Adding Why to What" on 28t… https://t.co/Ts0s7oi3Q9',
#   'Len': 140,
#   'Date Time': '2019-03-27 16:09:09',
#   'Likes': 4,
#   'Retweets': 1},
#  {'Tweets': 'RT @ylecun: I am extremely honored to be the recipient of the 2018 ACM A.M. Turing Award, and absolutely delighted to be sharing it with my…',
#   'Len': 140,
#   'Date Time': '2019-03-27 11:53:40',
#   'Likes': 0,
#   'Retweets': 1545},
#  {'Tweets': 'Thanks to all shortlisted candidates for submitting their solutions for @midasIIITD internship task 2019. We are cu… https://t.co/It6mumE8jN',
#   'Len': 140,
#   'Date Time': '2019-03-26 18:12:27',
#   'Likes': 5,
#   'Retweets': 1},
#  {'Tweets': '@IEEEBigMM19 @ACMMM19 and 6 days left for workshop proposal in @IEEEBigMM19.\n\nContact @cchatto for any query.',
#   'Len': 109,
#   'Date Time': '2019-03-26 05:54:49',
#   'Likes': 2,
#   'Retweets': 0},
#  {'Tweets': 'RT @IEEEBigMM19: Hurry Up!\n6 Days left for Abstract Submission in @ACMMM19 \n45 Days left for Regular Paper Submission in @IEEEBigMM19 .\n\nHe…',
#   'Len': 140,
#   'Date Time': '2019-03-26 05:50:10',
#   'Likes': 0,
#   'Retweets': 3},
#  {'Tweets': 'Congratulations @midasIIITD students Simra Shahid @Simcyy and Nilay Shrivastava @NilayShri on getting selected for… https://t.co/Irr6SfKMZI',
#   'Len': 139,
#   'Date Time': '2019-03-25 13:01:57',
#   'Likes': 18,
#   'Retweets': 1},
#  {'Tweets': 'The last date for submitting a solution for the @midasIIITD internship task is 26th March midnight. We will not acc… https://t.co/9BMRhXfqw3',
#   'Len': 140,
#   'Date Time': '2019-03-24 18:44:01',
#   'Likes': 8,
#   'Retweets': 3},
#  {'Tweets': 'RT @IIITDelhi: @IIITDelhi invites application from Foreign Nationals/PIOs/NRIs/OCIs for admission to its https://t.co/u6kIuhIrGM and https:…',
#   'Len': 140,
#   'Date Time': '2019-03-24 18:26:02',
#   'Likes': 0,
#   'Retweets': 4},
#  {'Tweets': 'One more week is left to submit the workshop proposal to @IEEEBigMM19. \nLooking forward to your submission. For any… https://t.co/MeaYTlKGjg',
#   'Len': 140,
#   'Date Time': '2019-03-24 11:34:27',
#   'Likes': 4,
#   'Retweets': 0},
#  {'Tweets': 'RT @IEEEBigMM19: We are honored to have Dr. Chang Wen Chen (Chinese University Hong Kong @CUHKofficial ) and Dr. Roger Zimmermann (National…',
#   'Len': 140,
#   'Date Time': '2019-03-24 06:23:37',
#   'Likes': 0,
#   'Retweets': 5},
#  {'Tweets': 'RT @IEEEBigMM19: Distinguished researchers Dr. Rajiv Ratn Shah @RatnRajiv (@IIITDelhi , @midasIIITD ), Dr. Jianquan Liu (NEC Japan) and Dr.…',
#   'Len': 140,
#   'Date Time': '2019-03-24 06:23:14',
#   'Likes': 0,
#   'Retweets': 3},
#  {'Tweets': '@IEEEBigMM19 is also available on Facebook now. \nLIKE its Facebook page https://t.co/B3Q0zmmzXb  to get the regular… https://t.co/z8tfXY3fHj',
#   'Len': 140,
#   'Date Time': '2019-03-20 08:19:24',
#   'Likes': 1,
#   'Retweets': 1},
#  {'Tweets': 'RT @IEEEBigMM19: BigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposals  \n\nhttps://t.co/I4vqf8FE6K …  \nWhen: Sep 11, 2019 - Sep 13, 201…',
#   'Len': 140,
#   'Date Time': '2019-03-20 02:40:07',
#   'Likes': 0,
#   'Retweets': 5},
#  {'Tweets': 'BigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposals\n\nhttps://t.co/oUq2G0UgKN\n\nWhen: Sep 11, 2019 - Sep 13, 2… https://t.co/HrZCI4APy9',
#   'Len': 140,
#   'Date Time': '2019-03-18 02:27:47',
#   'Likes': 6,
#   'Retweets': 3},
#  {'Tweets': 'Congratulations @midasIIITD team, Rohan, Pradyumn, Ramit, @debanjanbhucs, @MADAIguy and @RatnRajiv for getting thei… https://t.co/jDCOIOsl1M',
#   'Len': 140,
#   'Date Time': '2019-03-17 14:22:04',
#   'Likes': 15,
#   'Retweets': 4},
#  {'Tweets': 'We have emailed the task details to all shortlisted candidates for @midasIIITD internship. Kindly check the same.… https://t.co/ku8O8HaoOe',
#   'Len': 138,
#   'Date Time': '2019-03-16 14:06:56',
#   'Likes': 7,
#   'Retweets': 0},
#  {'Tweets': 'IEEE BigMM 2019 - Call for Workshop Proposals. \n\nContact @midasIIITD @RatnRajiv @debanjanbhucs if you have any quer… https://t.co/EArExUYJE4',
#   'Len': 140,
#   'Date Time': '2019-03-16 09:20:29',
#   'Likes': 2,
#   'Retweets': 1},
#  {'Tweets': 'Congratulations! Arijit, Ramit, @debanjanbhucs @RatnRajiv for your @NAACLHLT  @naacl SRW 2019 paper, "Speak Up, Fig… https://t.co/pc6pbJ9Iub',
#   'Len': 140,
#   'Date Time': '2019-03-16 09:14:58',
#   'Likes': 7,
#   'Retweets': 2},
#  {'Tweets': 'We will be releasing a very interesting task to shortlisted candidates for the internship at @midasIIITD today. You… https://t.co/PfjjoTNaWQ',
#   'Len': 140,
#   'Date Time': '2019-03-16 05:13:14',
#   'Likes': 7,
#   'Retweets': 2},
#  {'Tweets': 'RT @hcdiiitd: Last day to register for #PortfolioCreationinDesign Workshop Indraprastha Institute of Information Technology, Delhi on 15th…',
#   'Len': 139,
#   'Date Time': '2019-03-13 17:09:44',
#   'Likes': 0,
#   'Retweets': 2},
#  {'Tweets': '@ACMMM19 @sigmm @TheOfficialACM @acmmmsys @ACMTVX @ACMICMR @euromm @Benoit_Huet @RatnRajiv @kelkalot \nWe need to cl… https://t.co/ZofTZ3UcvN',
#   'Len': 140,
#   'Date Time': '2019-03-13 04:11:24',
#   'Likes': 1,
#   'Retweets': 0},
#  {'Tweets': 'RT @ACMMM19: The paper deadline is approaching. 1 April abstract is due. Authors will have until 8 April to upload the final PDF version of…',
#   'Len': 140,
#   'Date Time': '2019-03-13 04:06:04',
#   'Likes': 0,
#   'Retweets': 13},
#  {'Tweets': 'RT @kaggle: Bookmark this amazing library of image augmentations 😵 by #Kaggle Masters @AlBuslaev @creaf @viglovikov and @cvtalks | https://…',
#   'Len': 140,
#   'Date Time': '2019-03-12 17:43:44',
#   'Likes': 0,
#   'Retweets': 68},
#  {'Tweets': 'Awesome members of our @midasIIITD team who are working on Humonics projects. Great to have you on our team.… https://t.co/XEkcYO8KmW',
#   'Len': 133,
#   'Date Time': '2019-03-12 14:37:55',
#   'Likes': 16,
#   'Retweets': 4},
#  {'Tweets': '@saanidhi @ACMMM19 Before Friday, 15th March.',
#   'Len': 45,
#   'Date Time': '2019-03-11 14:58:30',
#   'Likes': 0,
#   'Retweets': 0},
#  {'Tweets': 'We are glad to inform that Adobe is launching Women’s day Tech-Challenge to hire female engineers from 2019 Batch u… https://t.co/vpNJyiuuqZ',
#   'Len': 140,
#   'Date Time': '2019-03-11 12:02:42',
#   'Likes': 4,
#   'Retweets': 0},
#  {'Tweets': 'We will email tasks to all shortlisted candidates for an internship at @midasIIITD by Friday, 15th March. If you ar… https://t.co/4TfRkzqpLu',
#   'Len': 140,
#   'Date Time': '2019-03-11 11:54:38',
#   'Likes': 3,
#   'Retweets': 0},
#  {'Tweets': '@ACMMM19 @ACM_MM2018 @acmmm17 @sigmm @ACM Less than three weeks are left for @ACMMM19 submission. \nLooking forward… https://t.co/XDubCfjQDu',
#   'Len': 139,
#   'Date Time': '2019-03-11 06:22:12',
#   'Likes': 1,
#   'Retweets': 1},
#  {'Tweets': 'RT @kdnuggets: Face Recognition using One-Shot Learning – #DeepLearning\nusing DL architecture that works great with one-shot learning calle…',
#   'Len': 140,
#   'Date Time': '2019-03-11 06:17:20',
#   'Likes': 0,
#   'Retweets': 64},
#  {'Tweets': '@AvinashSwamina2 @IIITDelhi No. They will be given tasks along with students who will be selected in the second round.',
#   'Len': 118,
#   'Date Time': '2019-03-08 13:22:07',
#   'Likes': 1,
#   'Retweets': 0},
#  {'Tweets': 'We are in the process of finalizing the shortlisted candidates for internship at @midasIIITD which we have received… https://t.co/DFMWvpSeMF',
#   'Len': 140,
#   'Date Time': '2019-03-08 13:15:34',
#   'Likes': 8,
#   'Retweets': 4},
#  {'Tweets': '@ylecun @NilayShri @the_dhumketu @debanjanbhucs will it be useful?',
#   'Len': 66,
#   'Date Time': '2019-03-06 13:44:11',
#   'Likes': 3,
#   'Retweets': 0},
#  {'Tweets': 'RT @kdnuggets: Python Data Science for Beginners https://t.co/yRExdmdZGh https://t.co/vRqTRuayO3',
#   'Len': 96,
#   'Date Time': '2019-03-06 11:12:30',
#   'Likes': 0,
#   'Retweets': 22},
#  {'Tweets': 'RT @stanfordnlp: Useful feature of our Python stanfordnlp: get lemmas &amp; morphology in many languages. Le ski de fond touché→lemma toucher f…',
#   'Len': 144,
#   'Date Time': '2019-03-03 19:36:04',
#   'Likes': 0,
#   'Retweets': 36},
#  {'Tweets': '@NilayShri @NilayShri, Certain thing! The next team outing will be for lipreading team. \nProbably, just after @ACMMM19 submission.',
#   'Len': 130,
#   'Date Time': '2019-03-03 17:09:48',
#   'Likes': 1,
#   'Retweets': 0},
#  {'Tweets': 'At @midasIIITD, we not only work hard but also have fun. \nToday, we had a team (for Humonics sponsored projects) ou… https://t.co/CmqbHYOcX8',
#   'Len': 140,
#   'Date Time': '2019-03-03 15:37:28',
#   'Likes': 9,
#   'Retweets': 1},
#  {'Tweets': 'Considering several requests to extend the deadline for internship application, @midasIIITD at @IIITDelhi has decid… https://t.co/wXHWiDrcG6',
#   'Len': 140,
#   'Date Time': '2019-03-03 14:55:31',
#   'Likes': 6,
#   'Retweets': 2},
#  {'Tweets': 'RT @jeremyphoward: 39 studies about human perception in 30 minutes by @kennelliott \n\nAwesome article. If you do any visualization or comput…',
#   'Len': 140,
#   'Date Time': '2019-03-03 14:26:40',
#   'Likes': 0,
#   'Retweets': 315},
#  {'Tweets': 'Correction:   @midasIIITD at @IIITDelhi',
#   'Len': 39,
#   'Date Time': '2019-03-02 17:43:05',
#   'Likes': 1,
#   'Retweets': 0},
#  {'Tweets': 'Thanks much to all aspirants who have applied for the summer internship 2019 at @midasIIITD at @midasIIITD. We have… https://t.co/jPV4qjnXC5',
#   'Len': 140,
#   'Date Time': '2019-03-02 09:59:03',
#   'Likes': 7,
#   'Retweets': 1},
#  {'Tweets': 'RT @kdnuggets: Keras Hyperparameter Tuning in Google Colab Using Hyperas https://t.co/hmaI4ukJRX https://t.co/s3nTqqgnAb',
#   'Len': 120,
#   'Date Time': '2019-02-28 14:21:21',
#   'Likes': 0,
#   'Retweets': 4},
#  {'Tweets': 'RT @RatnRajiv: Great meeting with @midasIIITD alumnus, Sanket Jain today.\nHe was among first MTech students who worked with me at @IIITDelh…',
#   'Len': 140,
#   'Date Time': '2019-02-26 18:30:52',
#   'Likes': 0,
#   'Retweets': 1},
#  {'Tweets': 'Correction: They have published the following paper only:\n\nPROMPT: Personalized User Tag Recommendation for Social… https://t.co/eBUbBzLFRO',
#   'Len': 139,
#   'Date Time': '2019-02-26 03:40:22',
#   'Likes': 0,
#   'Retweets': 0},
#  {'Tweets': 'We will process all applications received by March 1, 2019 and notify all shortlisted candidates by March 3. \n\nIf y… https://t.co/J5J0Lgq1HP',
#   'Len': 140,
#   'Date Time': '2019-02-25 16:10:46',
#   'Likes': 2,
#   'Retweets': 1},
#  {'Tweets': 'RT @ecsquendor: Jit Ghosh discusses the "GloVe" 2014 Stanford paper on word embeddings. This one was a great session! #paperreviewcalls #nl…',
#   'Len': 140,
#   'Date Time': '2019-02-24 03:39:40',
#   'Likes': 0,
#   'Retweets': 8},
#  {'Tweets': "RT @goodfellow_ian: This CVPR workshop is looking for applications of computer vision in developing countries. You don't need to submit a f…",
#   'Len': 140,
#   'Date Time': '2019-02-23 15:41:27',
#   'Likes': 0,
#   'Retweets': 90},
#  {'Tweets': 'RT @IIITDelhi: PhD Admission 2019 are open now\n\nOnline applications starts from 20th February 2019 and the last date to apply is 14th March…',
#   'Len': 140,
#   'Date Time': '2019-02-22 11:54:49',
#   'Likes': 0,
#   'Retweets': 8},
#  {'Tweets': 'RT @kdnuggets: #AI for Social Good study - how to inform policy, achieve interpretability, reduce bias and more -\ninclude review of global…',
#   'Len': 139,
#   'Date Time': '2019-02-21 16:27:54',
#   'Likes': 0,
#   'Retweets': 14},
#  {'Tweets': '@IIITDelhi has initiated PhD Admission 2019 process (Regular Round).\n\nOnline applications start from 20th February… https://t.co/cM1k4pNYy2',
#   'Len': 139,
#   'Date Time': '2019-02-21 06:39:27',
#   'Likes': 2,
#   'Retweets': 1},
#  {'Tweets': 'RT @radamihalcea: We tend to focus mainly on creating learning algorithms, and yet there is so much that can be gained from unlearning. In…',
#   'Len': 139,
#   'Date Time': '2019-02-21 04:48:24',
#   'Likes': 0,
#   'Retweets': 13},
#  {'Tweets': '@RealAAAI @RatnRajiv Thanks, @RealAAAI for recognizing our efforts. \n\nCongratulations, @midasIIITD students for win… https://t.co/S6gh6naEQX',
#   'Len': 140,
#   'Date Time': '2019-02-20 07:09:19',
#   'Likes': 6,
#   'Retweets': 3},
#  {'Tweets': 'Deepak Gupta, has joined @Google today. \nEarlier this week, Anupam Samanta, has also joined Google. \nBoth will be w… https://t.co/Ifj9K2YIHi',
#   'Len': 140,
#   'Date Time': '2019-02-20 05:38:29',
#   'Likes': 4,
#   'Retweets': 2},
#  {'Tweets': 'RT @ACMMM19: We are pleased to announce the multimedia Grand Challenges that will be offered at ACM Multimedia in 2019. Check out the list;…',
#   'Len': 140,
#   'Date Time': '2019-02-19 17:16:24',
#   'Likes': 0,
#   'Retweets': 15},
#  {'Tweets': 'In addition to projects related to NLP and Multimedia systems, we have open positions for 3D animation interns too.… https://t.co/Qmaqyc1B12',
#   'Len': 140,
#   'Date Time': '2019-02-19 04:29:33',
#   'Likes': 3,
#   'Retweets': 2},
#  {'Tweets': 'RT @technology: What could the manufacturing industry teach healthcare?',
#   'Len': 71,
#   'Date Time': '2019-02-19 04:19:05',
#   'Likes': 0,
#   'Retweets': 290},
#  {'Tweets': 'RT @MSFTResearch: Dr. Layla El Asri wants you to be able to talk to your machine just like you’d talk to another person. That’s the easy pa…',
#   'Len': 140,
#   'Date Time': '2019-02-19 04:18:53',
#   'Likes': 0,
#   'Retweets': 21},
#  {'Tweets': 'To apply for @midasIIITD internship at @IIITDelhi, fill the following form: https://t.co/t54AZ9eo26  \n\nCheck more d… https://t.co/n6bP8J51gc',
#   'Len': 140,
#   'Date Time': '2019-02-18 17:29:44',
#   'Likes': 11,
#   'Retweets': 9},
#  {'Tweets': 'RT @CornellDyson: Digital ag is Cornell’s newest radical collaboration initiative→https://t.co/hVXSnoSbnS\n#DigitalAg #Cornell @CornellNews…',
#   'Len': 139,
#   'Date Time': '2019-02-18 05:37:59',
#   'Likes': 0,
#   'Retweets': 6},
#  {'Tweets': 'RT @odsc: Introduction to StanfordNLP: a state-of-the-art NLP library for 53 languages @StanfordNLP #DataScience #NLP #NaturalLanguageProce…',
#   'Len': 140,
#   'Date Time': '2019-02-17 17:22:06',
#   'Likes': 0,
#   'Retweets': 51},
#  {'Tweets': 'Looking forward to your participation in Multimedia Grand Challenges of @ACMMM19 \n\nSeveral interesting challenges a… https://t.co/YmXiw41j9z',
#   'Len': 140,
#   'Date Time': '2019-02-17 09:02:28',
#   'Likes': 3,
#   'Retweets': 1},
#  {'Tweets': 'Consider attending National Workshop on Intelligent Multimodal Interfaces (NWIMI) at Indian Institute of Technology… https://t.co/sDi8fdT9oi',
#   'Len': 140,
#   'Date Time': '2019-02-17 08:49:36',
#   'Likes': 1,
#   'Retweets': 0},
#  {'Tweets': 'Submissions are invited for a special issue of Cognitive Computation (Impact Factor: 3.479) on Affect Recognition i… https://t.co/LkQb24vcGU',
#   'Len': 140,
#   'Date Time': '2019-02-17 06:39:30',
#   'Likes': 1,
#   'Retweets': 1},
#  {'Tweets': 'RT @debanjanbhucs: https://t.co/qNFzJ7ZHki',
#   'Len': 42,
#   'Date Time': '2019-02-16 16:57:51',
#   'Likes': 0,
#   'Retweets': 1},
#  {'Tweets': "RT @MSFTResearch: Congratulations to Manik Varma, @iitdelhi's Himanshu Jain, Venkatesh Balasubramanian and Bhanu Chunduri for winning the B…",
#   'Len': 140,
#   'Date Time': '2019-02-15 08:22:23',
#   'Likes': 0,
#   'Retweets': 13},
#  {'Tweets': 'Congratulations! Anupam Samanta on joining @Google as a software engineer. \n\nAnupam worked with @midasIIITD head, D… https://t.co/z9iljs6EP6',
#   'Len': 140,
#   'Date Time': '2019-02-14 15:56:14',
#   'Likes': 14,
#   'Retweets': 4},
#  {'Tweets': 'RT @kdnuggets: Using BERT for state-of-the-art pre-training for natural language processing https://t.co/wAyERwPw3r https://t.co/ghPTpClh3p',
#   'Len': 139,
#   'Date Time': '2019-02-13 18:56:13',
#   'Likes': 0,
#   'Retweets': 5},
#  {'Tweets': 'RT @ACMMM19: Attention authors of ACM MultiMedia 2018 and 2017 main conference papers. Submit a reproducibility paper to ACMMM 2019 https:/…',
#   'Len': 140,
#   'Date Time': '2019-02-13 15:54:52',
#   'Likes': 0,
#   'Retweets': 11},
#  {'Tweets': 'RT @kdnuggets: 9 Must-have skills you need to become a Data Scientist, updated https://t.co/OeeComtoWu https://t.co/DGq5qrQefc',
#   'Len': 126,
#   'Date Time': '2019-02-13 05:56:05',
#   'Likes': 0,
#   'Retweets': 11},
#  {'Tweets': '@ACMMM19 @ACM Just one week is left for workshop proposal. Kindly consider submitting it. \n@midasIIITD… https://t.co/BwEX4Q2x2t',
#   'Len': 127,
#   'Date Time': '2019-02-07 19:21:52',
#   'Likes': 1,
#   'Retweets': 1},
#  {'Tweets': '@NilayShri @the_dhumketu Thanks, @NilayShri for sharing. \nIndeed a very good work.',
#   'Len': 82,
#   'Date Time': '2019-02-07 15:49:59',
#   'Likes': 0,
#   'Retweets': 0},
#  {'Tweets': "RT @NilayShri: @midasIIITD @the_dhumketu this seems to be the 'trend' https://t.co/m6YfyTtwfX",
#   'Len': 93,
#   'Date Time': '2019-02-07 15:49:08',
#   'Likes': 0,
#   'Retweets': 1},
#  {'Tweets': 'RT @kdnuggets: Machine Learning in Python by @PyImageSearch\n"Struggling to get started with machine learning using Python? In this step-by-…',
#   'Len': 140,
#   'Date Time': '2019-02-07 06:23:10',
#   'Likes': 0,
#   'Retweets': 53},
#  {'Tweets': 'RT @Cambridge_Uni: .@DeepMindAI and @Cambridge_Trust  are offering scholarships to under-represented students to study computer science. Op…',
#   'Len': 140,
#   'Date Time': '2019-02-06 11:26:25',
#   'Likes': 0,
#   'Retweets': 35},
#  {'Tweets': 'RT @GoogleAI: Google AI  and @DeepMindAI researchers have open-sourced the Hanabi Learning Environment, a testbed for collaborative multi-a…',
#   'Len': 140,
#   'Date Time': '2019-02-05 18:32:54',
#   'Likes': 0,
#   'Retweets': 212},
#  {'Tweets': 'Edit: In the updated leaderboard we are now ranked 10th in the suggestion mining task! Thanks for updates @isarth23',
#   'Len': 115,
#   'Date Time': '2019-02-05 17:45:09',
#   'Likes': 0,
#   'Retweets': 0},
#  {'Tweets': 'Congratulations! @isarth23. \nIt is our pleasure to work with you. \nYou are a gem of @midasIIITD. https://t.co/mOJQyhd26K',
#   'Len': 120,
#   'Date Time': '2019-02-05 17:44:27',
#   'Likes': 4,
#   'Retweets': 0},
#  {'Tweets': 'In addition to OffensEval task, @midasIIITD has also performed well in the suggestion mining task (… https://t.co/Vs35HbjxlU',
#   'Len': 124,
#   'Date Time': '2019-02-05 12:09:44',
#   'Likes': 5,
#   'Retweets': 1},
#  {'Tweets': 'Thanks, Karan Uppal and @RatnRajiv for all your support.',
#   'Len': 56,
#   'Date Time': '2019-02-05 11:55:41',
#   'Likes': 1,
#   'Retweets': 1},
#  {'Tweets': '@midasIIITD performance in OffensEval 2019 (SemEval 2019 - Task 6).\n\nIn subtask-A, we came 5th out of 103 teams\nIn… https://t.co/nm6QEgp1EE',
#   'Len': 139,
#   'Date Time': '2019-02-05 11:06:31',
#   'Likes': 4,
#   'Retweets': 3},
#  {'Tweets': 'RT @ProfAnirban: One of the biggest obstacles to the adoption of #NLP and cognitive #AI is the lack of pretrained models in languages other…',
#   'Len': 140,
#   'Date Time': '2019-02-04 12:16:16',
#   'Likes': 0,
#   'Retweets': 39},
#  {'Tweets': 'RT @IIITDelhi: Students of @midasIIITD lab won the best student poster award at 33rd @RealAAAI 2019 conference in Honolulu, Hawaii for the…',
#   'Len': 139,
#   'Date Time': '2019-02-04 10:58:53',
#   'Likes': 0,
#   'Retweets': 4},
#  {'Tweets': '@RealAAAI 2019 summary for @midasIIITD.\n1 paper in main conference, 1 paper in EAAI, 2 papers published in student… https://t.co/NsZ70KKP9P',
#   'Len': 139,
#   'Date Time': '2019-02-02 05:05:16',
#   'Likes': 7,
#   'Retweets': 3},
#  {'Tweets': '@the_dhumketu @RealAAAI Congrats! Raghav, Kshitij, and @the_dhumketu for the best student poster award!\nCongrats… https://t.co/juj3RGiGU8',
#   'Len': 137,
#   'Date Time': '2019-02-01 07:46:57',
#   'Likes': 3,
#   'Retweets': 1},
#  {'Tweets': 'Our paper titled, "Mind Your Language: Abuse and Offence Detection for Code-Switched Languages", won the best stude… https://t.co/hV7uchpmWE',
#   'Len': 140,
#   'Date Time': '2019-02-01 07:30:53',
#   'Likes': 24,
#   'Retweets': 3},
#  {'Tweets': 'RT @PeterMartigny: Very interesting talk by @ChenguangZhu2 at the @stanfordnlp seminar on SDNet, a new architecture for conversational ques…',
#   'Len': 140,
#   'Date Time': '2019-02-01 03:15:27',
#   'Likes': 0,
#   'Retweets': 8},
#  {'Tweets': 'RT @NilayShri: @midasIIITD @RatnRajiv\n@the_dhumketu \nhttps://t.co/PkUa18lF8p',
#   'Len': 76,
#   'Date Time': '2019-02-01 03:13:23',
#   'Likes': 0,
#   'Retweets': 2},
#  {'Tweets': 'CFP for @ACMMM19 has been posted on WikiCFP. Kindly share with your colleagues and submit your work to #ACMMM 2019.… https://t.co/U2tLyg1Gjm',
#   'Len': 140,
#   'Date Time': '2019-01-31 06:57:04',
#   'Likes': 1,
#   'Retweets': 1},
#  {'Tweets': '@midasIIITD Lab is pleased to share our novel work titled, Harnessing GANs for Addition of New Classes in VSR (… https://t.co/BkSMWfWX8H',
#   'Len': 136,
#   'Date Time': '2019-01-31 05:50:19',
#   'Likes': 4,
#   'Retweets': 2},
#  {'Tweets': 'RT @RatnRajiv: If you are attending @RealAAAI and liked our work, Lipper, for speech reconstruction from silent videos using lipreading the…',
#   'Len': 140,
#   'Date Time': '2019-01-31 05:32:43',
#   'Likes': 0,
#   'Retweets': 2},
#  {'Tweets': "RT @RatnRajiv: Great to be part of this year's accepted papers at @RealAAAI from India. Out of 25 papers from India, 6 from @IIITDelhi. \nCo…",
#   'Len': 140,
#   'Date Time': '2019-01-30 19:46:11',
#   'Likes': 0,
#   'Retweets': 2},
#  {'Tweets': 'RT @MIT: Want to squelch fake news? Let the readers take charge https://t.co/Jusr6TMUse https://t.co/KDHmFDP9aE',
#   'Len': 111,
#   'Date Time': '2019-01-30 17:18:40',
#   'Likes': 0,
#   'Retweets': 11},
#  {'Tweets': 'If you are attending @RealAAAI 2019 at Honolulu, Hawaii, USA then attend our talk in the Student Abstract Session f… https://t.co/QPyeEUKWws',
#   'Len': 140,
#   'Date Time': '2019-01-30 05:00:29',
#   'Likes': 3,
#   'Retweets': 1},
#  {'Tweets': 'If you are attending @RealAAAI 2019 then visit following sessions for our papers.\n\n3. Lipper: Synthesizing Thy Spee… https://t.co/C4G5ldlFt4',
#   'Len': 140,
#   'Date Time': '2019-01-29 19:42:10',
#   'Likes': 5,
#   'Retweets': 2},
#  {'Tweets': 'If you are attending @RealAAAI 2019 then visit following sessions for our papers.\n\n2. Lipper: Speaker Independent S… https://t.co/ytddMaL0V3',
#   'Len': 140,
#   'Date Time': '2019-01-29 19:39:29',
#   'Likes': 3,
#   'Retweets': 1},
#  {'Tweets': 'If you are attending @RealAAAI 2019 then visit following sessions for our papers.\n\n1. Mind Your Language: Abuse and… https://t.co/i1q32HQSGM',
#   'Len': 140,
#   'Date Time': '2019-01-29 19:31:35',
#   'Likes': 2,
#   'Retweets': 1},
#  {'Tweets': '@TechAtBloomberg @debanjanbhucs It is a great experience to work with @debanjanbhucs.\n@midasIIITD looks forward to… https://t.co/RgwF3FZdki',
#   'Len': 139,
#   'Date Time': '2019-01-29 18:05:01',
#   'Likes': 5,
#   'Retweets': 2},
#  {'Tweets': 'RT @TechAtBloomberg: Learn more about the collaborative efforts of researchers @debanjanbhucs &amp; Daniel Preoţiuc-Pietro w/ academics around…',
#   'Len': 143,
#   'Date Time': '2019-01-29 18:03:31',
#   'Likes': 0,
#   'Retweets': 5},
#  {'Tweets': 'RT @debanjanbhucs: We as researchers working at Bloomberg also get opportunities to collaborate with academia. Here are the outcomes of two…',
#   'Len': 140,
#   'Date Time': '2019-01-29 17:52:23',
#   'Likes': 0,
#   'Retweets': 2},
#  {'Tweets': 'RT @kdnuggets: 7 Steps to Mastering Basic Machine Learning with Python — 2019 Edition\n https://t.co/yZExGjOVWH https://t.co/sJC8p2kTyp',
#   'Len': 134,
#   'Date Time': '2019-01-29 14:52:24',
#   'Likes': 0,
#   'Retweets': 32},
#  {'Tweets': '@TechAtBloomberg @debanjanbhucs @IIITDelhi @RatnRajiv Congrats, team @midasIIITD! https://t.co/ncsgSUusUb',
#   'Len': 105,
#   'Date Time': '2019-01-29 05:17:27',
#   'Likes': 3,
#   'Retweets': 1},
#  {'Tweets': 'RT @TechAtBloomberg: #Textanalytics researcher @debanjanbhucs joins @IIITDelhi\'s @RatnRajiv &amp; other co-authors to present "Get IT Scored us…',
#   'Len': 144,
#   'Date Time': '2019-01-29 04:40:47',
#   'Likes': 0,
#   'Retweets': 5},
#  {'Tweets': 'RT @kdnuggets: Top 16 #OpenSource #DeepLearning Libraries and Platforms #KDN https://t.co/TycxmMSCWs',
#   'Len': 100,
#   'Date Time': '2019-01-28 12:11:29',
#   'Likes': 0,
#   'Retweets': 8},
#  {'Tweets': 'RT @Princeton: Using data from more than 6,000 patients, @EPrinceton researchers applied #machinelearning methods to design a system that c…',
#   'Len': 140,
#   'Date Time': '2019-01-28 12:11:13',
#   'Likes': 0,
#   'Retweets': 20},
#  {'Tweets': 'RT @CornellBirds: In 1929 Cornell Lab founder Arthur Allen made the very first recordings of wild birds. Follow @MacaulayLibrary as they sh…',
#   'Len': 140,
#   'Date Time': '2019-01-28 12:10:37',
#   'Likes': 0,
#   'Retweets': 67},
#  {'Tweets': 'RT @seb_ruder: Natural Questions: A new QA dataset consisting of 300,000+ naturally occurring questions (posed to Google search) with human…',
#   'Len': 140,
#   'Date Time': '2019-01-25 08:56:54',
#   'Likes': 0,
#   'Retweets': 141},
#  {'Tweets': 'RT @kdnuggets: 10 More #Free Must-Read #Books for #MachineLearning and #DataScience #KDN https://t.co/EtMyAJFl6d',
#   'Len': 112,
#   'Date Time': '2019-01-24 15:43:25',
#   'Likes': 0,
#   'Retweets': 24},
#  {'Tweets': 'RT @kdnuggets: How to build an API for a machine learning model in 5 minutes using Flask https://t.co/VFN7NmCqTu https://t.co/oZ8rXEGM5w',
#   'Len': 136,
#   'Date Time': '2019-01-24 15:42:59',
#   'Likes': 0,
#   'Retweets': 25},
#  {'Tweets': '@ACMMM19 @ACM @abhinavdhall consider submitting your proposal.',
#   'Len': 62,
#   'Date Time': '2019-01-23 10:24:14',
#   'Likes': 0,
#   'Retweets': 0},
#  {'Tweets': 'RT @ACMMM19: Jump start your @ACM #Multimedia workshop submission... First workshop titles are now online https://t.co/S9ZSaJTH1a But also…',
#   'Len': 139,
#   'Date Time': '2019-01-23 10:23:34',
#   'Likes': 0,
#   'Retweets': 10},
#  {'Tweets': '@NUSComputing Congratulations! Yaman @the_dhumketu , Roger, Yifang, @RatnRajiv, Rohit, and Salik.',
#   'Len': 97,
#   'Date Time': '2019-01-22 14:04:40',
#   'Likes': 1,
#   'Retweets': 1},
#  {'Tweets': '⚡️ “Achievements”\n\nhttps://t.co/LvZt1GTY4C',
#   'Len': 42,
#   'Date Time': '2019-01-22 14:02:51',
#   'Likes': 3,
#   'Retweets': 1},
#  {'Tweets': 'RT @NUSComputing: A/P Roger Zimmermann and his collaborators from IIIT Delhi developed a lipreading system that produces audio from lip mov…',
#   'Len': 140,
#   'Date Time': '2019-01-22 13:58:08',
#   'Likes': 0,
#   'Retweets': 2},
#  {'Tweets': 'Welcome one member to our @midasIIITD family, SkyWalker. \nIt will strengthen our team with Falcon. \n\n#midas #server… https://t.co/IIZ8ZhVDJg',
#   'Len': 140,
#   'Date Time': '2019-01-21 16:29:31',
#   'Likes': 9,
#   'Retweets': 1},
#  {'Tweets': 'Dr @RatnRajiv Shah delivered a research talk in the National Symposium on Natural Languages Processing and Artifici… https://t.co/YnxUtsbalX',
#   'Len': 140,
#   'Date Time': '2019-01-21 15:19:33',
#   'Likes': 6,
#   'Retweets': 2},
#  {'Tweets': "RT @Scott__Hubbard: Don't miss this new article from @ted_dunning, who presents practical methods for near real-time monitoring of machine…",
#   'Len': 139,
#   'Date Time': '2019-01-21 09:33:03',
#   'Likes': 0,
#   'Retweets': 9},
#  {'Tweets': 'RT @kaggle: Stuck inside with stir-crazy kids? 😫🤒😵Check out these downloadable machine learning projects designed for kids aged 8-16 👉https…',
#   'Len': 140,
#   'Date Time': '2019-01-21 09:32:03',
#   'Likes': 0,
#   'Retweets': 37},
#  {'Tweets': '@Princeton @nyuniversity @nytimes Team @midasIIITD, do we have the same trend in India?',
#   'Len': 87,
#   'Date Time': '2019-01-21 06:54:14',
#   'Likes': 0,
#   'Retweets': 0},
#  {'Tweets': 'RT @Harvard: Researchers find connections between worry and the development of heart disease https://t.co/yQ4miy8DHI',
#   'Len': 116,
#   'Date Time': '2019-01-20 05:49:19',
#   'Likes': 0,
#   'Retweets': 77},
#  {'Tweets': 'RT @Stanford: Researchers across Stanford are exploring ways to predict and prevent preterm births, and to improve care for the highest-ris…',
#   'Len': 140,
#   'Date Time': '2019-01-19 18:15:35',
#   'Likes': 0,
#   'Retweets': 8},
#  {'Tweets': 'Meet our members of @midasIIITD .\n\nhttps://t.co/2PFbtoDtDR\n\nWe welcome new members to our group. \n\nMIDAS is a group… https://t.co/wpUTuw9Lf4',
#   'Len': 140,
#   'Date Time': '2019-01-19 09:59:16',
#   'Likes': 7,
#   'Retweets': 2},
#  {'Tweets': 'RT @kdnuggets: How to Monitor Machine Learning Models in Real-Time https://t.co/9UpYVzlQWI https://t.co/9lK9eoOVWe',
#   'Len': 114,
#   'Date Time': '2019-01-19 03:27:33',
#   'Likes': 0,
#   'Retweets': 9},
#  {'Tweets': 'Congratulations! @Leomi7 @ashualloy @RatnRajiv Ayush, Himanshu, Aditya, Deepanshu, @isarth23 @rgrgrajat1',
#   'Len': 104,
#   'Date Time': '2019-01-18 10:25:41',
#   'Likes': 6,
#   'Retweets': 0},
#  {'Tweets': 'RT @jasonbaumgartne: #Pushshift is happy to announce a new dataset for your ML / NLP / Research pleasure -- Data for over 340+ Stackexchang…',
#   'Len': 140,
#   'Date Time': '2019-01-18 10:17:02',
#   'Likes': 0,
#   'Retweets': 20},
#  {'Tweets': 'Proceedings of FIRE 2018 is online now at https://t.co/vzLpwVp1Qb\nOur 4 papers are:\n1. Fully Automatic Approach to… https://t.co/UzZiKlthB9',
#   'Len': 139,
#   'Date Time': '2019-01-18 10:16:26',
#   'Likes': 10,
#   'Retweets': 2},
#  {'Tweets': 'RT @hseas: Only 20 percent of pediatric cancer patients in lower- and middle-income countries will survive. Engineering students partnered…',
#   'Len': 139,
#   'Date Time': '2019-01-17 04:04:16',
#   'Likes': 0,
#   'Retweets': 26},
#  {'Tweets': 'RT @Cornell: Can virtual reality transform medicine? Psychologist JoAnn Difede @WeillCornell began using #VR with soldiers and survivors fr…',
#   'Len': 140,
#   'Date Time': '2019-01-17 04:03:55',
#   'Likes': 0,
#   'Retweets': 11},
#  {'Tweets': 'RT @kdnuggets: Explainable Artificial Intelligence https://t.co/rllNxnm73U https://t.co/mAYFPMJF8P',
#   'Len': 98,
#   'Date Time': '2019-01-13 16:45:48',
#   'Likes': 0,
#   'Retweets': 20},
#  {'Tweets': '@abhinavdhall @RatnRajiv Emailed you.',
#   'Len': 37,
#   'Date Time': '2019-01-13 16:40:46',
#   'Likes': 0,
#   'Retweets': 0},
#  {'Tweets': 'RT @kdnuggets: A comprehensive list of #MachineLearning Resources: Open Courses, Textbooks, #Tutorials, Cheat Sheets and more #KDN https://…',
#   'Len': 140,
#   'Date Time': '2019-01-13 16:03:25',
#   'Likes': 0,
#   'Retweets': 41},
#  {'Tweets': 'Call for Book Chapter- Springer- Deep learning based approaches for sentiment analysis. Contact for more details.… https://t.co/LgtvlSpETQ',
#   'Len': 138,
#   'Date Time': '2019-01-13 07:19:19',
#   'Likes': 6,
#   'Retweets': 1},
#  {'Tweets': 'RT @Stanford: The average woman is exposed to four medications during her pregnancy and over 80 percent of medications haven’t been studied…',
#   'Len': 140,
#   'Date Time': '2019-01-12 14:37:07',
#   'Likes': 0,
#   'Retweets': 48},
#  {'Tweets': '@harvardmed @Harvard Another interesting direction to our previous work @MADAIguy @Leomi7',
#   'Len': 89,
#   'Date Time': '2019-01-10 08:51:20',
#   'Likes': 1,
#   'Retweets': 0},
#  {'Tweets': 'RT @harvardmed: A first-of-its-kind strategy aims to improve outcomes for kidney cancer patients who are at high risk of recurrence followi…',
#   'Len': 140,
#   'Date Time': '2019-01-10 08:50:35',
#   'Likes': 0,
#   'Retweets': 27},
#  {'Tweets': 'RT @RatnRajiv: Fortunate to have appreciation from my former NUS professor, Dr. Terence Sim.\nHe also appreciated our @RealAAAI\n2019 paper o…',
#   'Len': 140,
#   'Date Time': '2019-01-10 08:48:17',
#   'Likes': 0,
#   'Retweets': 3},
#  {'Tweets': 'RT @Harvard: The study provides potential future targets for drug development to treat osteoporosis https://t.co/YhfrOovdbO',
#   'Len': 123,
#   'Date Time': '2019-01-09 02:05:06',
#   'Likes': 0,
#   'Retweets': 9},
#  {'Tweets': 'RT @UniofOxford: In the final episode of series one of our Futuremakers podcast series, hear from Professor Sir @Nigel_Shadbolt on where th…',
#   'Len': 140,
#   'Date Time': '2019-01-07 09:05:12',
#   'Likes': 0,
#   'Retweets': 16},
#  {'Tweets': '@ACMMM19: Call for Workshop Proposals \n\nDeadline: Friday 15 February 2019\n\nhttps://t.co/vpdx97ucNP\n\n#ACMMM19… https://t.co/tsZdIKtonM',
#   'Len': 133,
#   'Date Time': '2019-01-06 12:54:06',
#   'Likes': 1,
#   'Retweets': 0},
#  {'Tweets': '@ACMMM19: Call for Grand Challenge Proposals\n\nDeadline: Tuesday 8 January 2019\n\nCheck more details at-… https://t.co/MHDI87AXTv',
#   'Len': 127,
#   'Date Time': '2019-01-06 04:29:25',
#   'Likes': 1,
#   'Retweets': 0},
#  {'Tweets': 'Since 1993, ACM Multimedia has been bringing together researchers and practitioners from academia and industry to p… https://t.co/dgqhsabXtF',
#   'Len': 140,
#   'Date Time': '2019-01-06 04:09:54',
#   'Likes': 5,
#   'Retweets': 1},
#  {'Tweets': '@ACMMM19 is structured around four themes (alphabetical):\n\nEngaging users with multimedia\nMultimedia experience\nMul… https://t.co/WBVqNC0j90',
#   'Len': 140,
#   'Date Time': '2019-01-06 04:07:29',
#   'Likes': 1,
#   'Retweets': 0},
#  {'Tweets': 'ACM Multimedia 2019: First Call for Papers/Call for Contributions\n@ACMMM19 is the premier international conference… https://t.co/jYb2y1ri2x',
#   'Len': 139,
#   'Date Time': '2019-01-06 04:05:38',
#   'Likes': 4,
#   'Retweets': 2},
#  {'Tweets': 'RT @ACMMM19: Happy new year! 2019 started with a bang. Thanks to everyone working to help resolve the ACM webserver hack issues. Please wat…',
#   'Len': 140,
#   'Date Time': '2019-01-03 06:14:05',
#   'Likes': 0,
#   'Retweets': 2},
#  {'Tweets': 'You may follow @midasIIITD updates through following:\n\nWebsite: https://t.co/sPvbKhflKQ\nFacebook:… https://t.co/n0lhKok55x',
#   'Len': 122,
#   'Date Time': '2019-01-01 17:21:49',
#   'Likes': 4,
#   'Retweets': 2},
#  {'Tweets': 'Today, @midasIIITD completed one year at @IIITDelhi. In last one year, we have shown our strong presence in researc… https://t.co/UPFHOJOVne',
#   'Len': 140,
#   'Date Time': '2019-01-01 17:17:56',
#   'Likes': 14,
#   'Retweets': 5},
#  {'Tweets': 'RT @debanjanbhucs: Happy anniversary to @midasIIITD . It surely has been a productive year for us and hope to see some ground breaking work…',
#   'Len': 140,
#   'Date Time': '2019-01-01 16:14:24',
#   'Likes': 0,
#   'Retweets': 4},
#  {'Tweets': 'Two Research Assistant (RA) positions are still open. Contact us if you are eligible and interested to work on the… https://t.co/pWwA5lBwUk',
#   'Len': 139,
#   'Date Time': '2018-12-27 10:28:31',
#   'Likes': 2,
#   'Retweets': 1},
#  {'Tweets': 'Positions for two Research Assistants (RA) are still open at @midasIIITD. Interested candidates may send their CV a… https://t.co/YyIFinU41I',
#   'Len': 140,
#   'Date Time': '2018-12-27 09:59:06',
#   'Likes': 5,
#   'Retweets': 3},
#  {'Tweets': 'RT @TCoolsIT: I wrote a blogpost on CoreNLP highlighting some of its functionality. If you want a quick dip before diving into the course,…',
#   'Len': 139,
#   'Date Time': '2018-12-27 02:33:58',
#   'Likes': 0,
#   'Retweets': 12},
#  {'Tweets': '@RatnRajiv delivered a research talk at the Central Research Laboratories of NEC Corporation, Japan. He discussed s… https://t.co/nQiLhO9zkD',
#   'Len': 140,
#   'Date Time': '2018-12-26 09:41:04',
#   'Likes': 14,
#   'Retweets': 2},
#  {'Tweets': '@midasIIITD look forward to work together. https://t.co/nrpf32ODo2',
#   'Len': 66,
#   'Date Time': '2018-12-25 04:15:15',
#   'Likes': 1,
#   'Retweets': 0},
#  {'Tweets': '@the_dhumketu @punnibhai @Hitkul_, FYI. https://t.co/yZb9mdr6IB',
#   'Len': 63,
#   'Date Time': '2018-12-25 03:00:21',
#   'Likes': 2,
#   'Retweets': 1},
#  {'Tweets': 'RT @iiit_hyderabad: KCIS Distinguished Lecture by Andrew Zisserman on Learning from Sight and Sound. Three-time Marr Prize winner Zisserman…',
#   'Len': 140,
#   'Date Time': '2018-12-24 07:39:21',
#   'Likes': 0,
#   'Retweets': 11},
#  {'Tweets': 'RT @StanfordAILab: Our latest blog post is out! \n\nCheck it out for a recording and summary of highlights from the event "AI and the Future…',
#   'Len': 139,
#   'Date Time': '2018-12-21 03:50:39',
#   'Likes': 0,
#   'Retweets': 32},
#  {'Tweets': 'RT @medialab: In two new papers, @PratikShahPhD and collaborators present novel #AI and machine learning methods to improve diagnosis at th…',
#   'Len': 140,
#   'Date Time': '2018-12-20 18:05:35',
#   'Likes': 0,
#   'Retweets': 8},
#  {'Tweets': 'RT @RatnRajiv: Wonderful get together with our NII colleagues. Prior to that we had a wonderful talk with Prof Chua Tat-Seng from National…',
#   'Len': 139,
#   'Date Time': '2018-12-20 06:14:52',
#   'Likes': 0,
#   'Retweets': 3},
#  {'Tweets': '@ACMMM19 is the premier international conference in the area of multimedia within the field of computer science. Mu… https://t.co/8lKiTK7FBY',
#   'Len': 140,
#   'Date Time': '2018-12-19 02:16:31',
#   'Likes': 2,
#   'Retweets': 3},
#  {'Tweets': 'Feel free to contact us if you have any query on @ACMMM19. We look forward to your submissions to ACM Multimedia co… https://t.co/616EFI1MVE',
#   'Len': 140,
#   'Date Time': '2018-12-18 14:42:27',
#   'Likes': 3,
#   'Retweets': 2},
#  {'Tweets': '@NilayShri @RatnRajiv @ACMMM19 Looking forward to your paper to @ACMMM19.',
#   'Len': 73,
#   'Date Time': '2018-12-18 14:27:12',
#   'Likes': 3,
#   'Retweets': 0},
#  {'Tweets': '@midasIIITD head, Dr. @RatnRajiv appointed as one of the publicity co-chairs for @ACMMM19. ACM Multimedia is the pr… https://t.co/QIGDlmunLN',
#   'Len': 140,
#   'Date Time': '2018-12-18 14:15:32',
#   'Likes': 12,
#   'Retweets': 5},
#  {'Tweets': '@ACMMM19 @the_dhumketu fill the volunteer form for reviewer.',
#   'Len': 60,
#   'Date Time': '2018-12-18 12:34:10',
#   'Likes': 1,
#   'Retweets': 0},
#  {'Tweets': 'RT @ACMMM19: New in 2019! Volunteer to serve as ACM Multimedia Area Chair or Reviewer. Please provide information on your qualifications in…',
#   'Len': 140,
#   'Date Time': '2018-12-18 12:33:42',
#   'Likes': 0,
#   'Retweets': 7},
#  {'Tweets': 'RT @IIITDelhi: Congratulations! authors Yaman @the_dhumketu, @RatnRajiv, and team @midasIIITD for winning the best poster runner-up at 20th…',
#   'Len': 140,
#   'Date Time': '2018-12-18 04:38:35',
#   'Likes': 0,
#   'Retweets': 3},
#  {'Tweets': 'Best wishes to @midasIIITD students @_himanshu0113, @Hitkul_, and Shivangi on starting their research internship at… https://t.co/tL35MUcQvR',
#   'Len': 140,
#   'Date Time': '2018-12-17 16:57:00',
#   'Likes': 14,
#   'Retweets': 4},
#  {'Tweets': 'RT @MIT: Computer model could improve human-machine interaction, provide insight into how children learn language. https://t.co/ToQo6GTMcG…',
#   'Len': 139,
#   'Date Time': '2018-12-17 15:05:44',
#   'Likes': 0,
#   'Retweets': 20},
#  {'Tweets': 'RT @kdnuggets: Great @Wired interview with Geoff #Hinton on #AI risks, explanation, Graphcore chips, brain vs neural nets, and why there wi…',
#   'Len': 140,
#   'Date Time': '2018-12-17 14:37:00',
#   'Likes': 0,
#   'Retweets': 20},
#  {'Tweets': 'RT @harvardmed: A defective metabolic pathway in aging immune cells may explain why the elderly commonly experience weakened immunity https…',
#   'Len': 140,
#   'Date Time': '2018-12-17 14:05:47',
#   'Likes': 0,
#   'Retweets': 167},
#  {'Tweets': 'RT @stanfordnlp: Thread on (neural) reasoning. 👇 https://t.co/kyJs5xztwA',
#   'Len': 72,
#   'Date Time': '2018-12-16 15:01:20',
#   'Likes': 0,
#   'Retweets': 10},
#  {'Tweets': 'Congratulations! Yaman @the_dhumketu, Rohit, Salik, Yifang, Roger, @RatnRajiv for winning the best poster runner-up… https://t.co/7fAKUXLkgy',
#   'Len': 140,
#   'Date Time': '2018-12-12 03:56:19',
#   'Likes': 16,
#   'Retweets': 3},
#  {'Tweets': 'Yaman @the_dhumketu presented our idea of reconstructing speech from silent videos based on lip movements in the "B… https://t.co/nIDfysu8Ry',
#   'Len': 140,
#   'Date Time': '2018-12-01 15:24:51',
#   'Likes': 20,
#   'Retweets': 4},
#  {'Tweets': 'Several Research Assistant and Intern positions are available at @midasIIITD lab. Check https://t.co/tfdisnpfw1 for… https://t.co/zLvYxkt5Ht',
#   'Len': 140,
#   'Date Time': '2018-11-21 04:08:34',
#   'Likes': 11,
#   'Retweets': 10},
#  {'Tweets': 'RT @kdnuggets: Variational Autoencoders Explained – Towards Data Science https://t.co/g2HC2ne5DW https://t.co/CHkAMeYoNz',
#   'Len': 120,
#   'Date Time': '2018-11-20 09:05:09',
#   'Likes': 0,
#   'Retweets': 10},
#  {'Tweets': 'Positions for research assistants and interns are open at the @midasIIITD Lab. Check https://t.co/tfdisn7E7r for mo… https://t.co/u6sJW3IsbU',
#   'Len': 140,
#   'Date Time': '2018-11-19 10:23:49',
#   'Likes': 2,
#   'Retweets': 4},
#  {'Tweets': 'Congratulations @Leomi7 Meghna, @punnibhai Puneet, @RatnRajiv, and Dr. Shree Gopal Sharma for getting your paper, E… https://t.co/Awighdq7cX',
#   'Len': 140,
#   'Date Time': '2018-11-05 19:33:31',
#   'Likes': 7,
# ...
#   'Len': 140,
#   'Date Time': '2018-08-28 13:56:15',
#   'Likes': 7,
#   'Retweets': 0},
#  {'Tweets': 'RT @jain49: Great to hear this.  #FoodComputing #FutureHealth https://t.co/qH1zns8MpG',
#   'Len': 85,
#   'Date Time': '2018-08-26 17:13:49',
#   'Likes': 0,
#   'Retweets': 1},
#  {'Tweets': '@ponguru @IIITDelhi @AhujaSheetu @DheerajSanghi Best wishes to all graduates of @IIITDelhi. \n@midasIIITD looks forw… https://t.co/Uj3bJv8Fh1',
#   'Len': 140,
#   'Date Time': '2018-08-25 05:05:20',
#   'Likes': 2,
#   'Retweets': 1},
#  {'Tweets': 'RT @kdnuggets: Understanding Deep Convolutional #NeuralNetworks with a practical use-case in Tensorflow and Keras #KDN https://t.co/Yiop03C…',
#   'Len': 140,
#   'Date Time': '2018-08-24 04:59:43',
#   'Likes': 0,
#   'Retweets': 32},
#  {'Tweets': 'RT @hardmaru: Everybody Dance Now!\nExciting new work on conditional video synthesis from Berkeley.\nhttps://t.co/kXGsZ8O4zA https://t.co/TuS…',
#   'Len': 140,
#   'Date Time': '2018-08-24 04:59:16',
#   'Likes': 0,
#   'Retweets': 8427},
#  {'Tweets': 'RT @YejinChoinka: We have a hot new dataset for 🔥NLI with commonsense🔥! --- 113k multiple choice questions adversarially constructed to mak…',
#   'Len': 140,
#   'Date Time': '2018-08-23 17:28:15',
#   'Likes': 0,
#   'Retweets': 77},
#  {'Tweets': 'RT @radamihalcea: We are releasing a brand new dataset of fake news, covering several domains\nhttps://t.co/aq5s3rV7ti\n\nRead the paper here…',
#   'Len': 139,
#   'Date Time': '2018-08-23 15:56:47',
#   'Likes': 0,
#   'Retweets': 83},
#  {'Tweets': '"Did you offend me? Classification of Offensive Tweets in Hinglish Language."\n\nMany congratulations to @midasIIITD… https://t.co/YHwqMmF8HG',
#   'Len': 139,
#   'Date Time': '2018-08-23 14:48:45',
#   'Likes': 6,
#   'Retweets': 1},
#  {'Tweets': 'Congratulations @midasIIITD interns, @punnibhai Puneet, @Leomi7 Meghna, Sahil Chopra, Simra Shahid, and Laiba Mehna… https://t.co/4WZe8TMp2P',
#   'Len': 140,
#   'Date Time': '2018-08-23 09:01:29',
#   'Likes': 7,
#   'Retweets': 2},
#  {'Tweets': 'https://t.co/GOyrocgXf4',
#   'Len': 23,
#   'Date Time': '2018-08-23 07:19:47',
#   'Likes': 8,
#   'Retweets': 1},
#  {'Tweets': 'TCS Foundation inaugurated Centre for Design and New Media at @IIITDelhi. @midasIIITD is proud to be the part of th… https://t.co/aNIurRQqm8',
#   'Len': 140,
#   'Date Time': '2018-08-23 07:17:40',
#   'Likes': 8,
#   'Retweets': 3},
#  {'Tweets': '@RatnRajiv Another paper will help companies or people to find offensive tweets in Hinglish automatically. Our meth… https://t.co/b01NGnU6tS',
#   'Len': 140,
#   'Date Time': '2018-08-23 03:38:51',
#   'Likes': 2,
#   'Retweets': 1},
#  {'Tweets': 'Congratulations all @midasIIITD interns for your great work. \nOne of our accepted work will help patients to reach… https://t.co/w9mQgB2Lrq',
#   'Len': 139,
#   'Date Time': '2018-08-23 03:34:39',
#   'Likes': 4,
#   'Retweets': 2},
#  {'Tweets': '@Thom_Wolf @stanfordnlp @sivareddyg @hhexiy @yatskar @MohitIyyer @the_dhumketu @RatnRajiv \nA great scope to work on this dataset.',
#   'Len': 129,
#   'Date Time': '2018-08-23 03:31:55',
#   'Likes': 1,
#   'Retweets': 0},
#  {'Tweets': '@danqi_chen @stanfordnlp FYI @the_dhumketu',
#   'Len': 42,
#   'Date Time': '2018-08-22 19:22:16',
#   'Likes': 1,
#   'Retweets': 0},
#  {'Tweets': 'RT @kdnuggets: Awesome #DeepLearning: Most Cited #DeepLearning Papers #KDN https://t.co/szGieAzboH',
#   'Len': 98,
#   'Date Time': '2018-08-22 16:11:43',
#   'Likes': 0,
#   'Retweets': 33},
#  {'Tweets': 'RT @stanfordnlp: People usually get information from others in a multi-turn conversation. To approach this, we’ve released CoQA 🍃—A Convers…',
#   'Len': 140,
#   'Date Time': '2018-08-22 15:50:12',
#   'Likes': 0,
#   'Retweets': 233},
#  {'Tweets': 'Team @midasIIITD looking forward to with CDNM. https://t.co/h4roiaL1X6',
#   'Len': 70,
#   'Date Time': '2018-08-22 12:53:38',
#   'Likes': 4,
#   'Retweets': 1},
#  {'Tweets': 'RT @VeredShwartz: After 3 years of blogging about NLP, with the goal of writing in simple words that non-experts can understand, I finally…',
#   'Len': 139,
#   'Date Time': '2018-08-22 05:35:37',
#   'Likes': 0,
#   'Retweets': 61},
#  {'Tweets': "RT @msisodia: With immense ambition &amp; hope, inaugurated the sprawling @IIITDelhi Phase 2 Campus with Hon'ble CM @ArvindKejriwal \n\nThe total…",
#   'Len': 144,
#   'Date Time': '2018-08-22 04:56:37',
#   'Likes': 0,
#   'Retweets': 496},
#  {'Tweets': 'RT @goodfellow_ian: Video-to-video translation with conditional GANs https://t.co/DDmRSTkpri',
#   'Len': 92,
#   'Date Time': '2018-08-22 04:56:22',
#   'Likes': 0,
#   'Retweets': 87},
#  {'Tweets': "RT @kaggle: RT @afshinea 🔥Set of illustrated Machine Learning cheat sheets from Stanford's CS 229 class:\nDeep Learning: https://t.co/BNQ7Fp…",
#   'Len': 140,
#   'Date Time': '2018-08-22 04:56:17',
#   'Likes': 0,
#   'Retweets': 554},
#  {'Tweets': 'RT @jain49: Beginning to understand what we eat better. Next, controlling it through engineering. #FoodComputing https://t.co/PpMwnqFvak vi…',
#   'Len': 140,
#   'Date Time': '2018-08-20 05:41:16',
#   'Likes': 0,
#   'Retweets': 1},
#  {'Tweets': 'Our paper titled, "IceBreaker: Solving Cold Start Problem for Video\nRecommendation Engines", is now available on Ar… https://t.co/vv4eAFATn6',
#   'Len': 140,
#   'Date Time': '2018-08-20 04:32:09',
#   'Likes': 3,
#   'Retweets': 1},
#  {'Tweets': 'RT @mr2amc: Call for papers: MR2AMC 2018, Taichung, Taiwan.\n\nhttps://t.co/gBhtnsyUk3',
#   'Len': 84,
#   'Date Time': '2018-08-20 03:51:43',
#   'Likes': 0,
#   'Retweets': 1},
#  {'Tweets': 'Our paper titled, "Neural Machine Translation for English-Tamil", is got accepted to the third Conference on Machin… https://t.co/44Oq7l8Lek',
#   'Len': 140,
#   'Date Time': '2018-08-19 09:19:12',
#   'Likes': 9,
#   'Retweets': 0},
#  {'Tweets': 'RT @mr2amc: Team @midasIIITD, please spread CFP for @mr2amc \n\n#ISM #MR2AMC #IEEE #MIDAS https://t.co/D2ZJjYR8N4',
#   'Len': 111,
#   'Date Time': '2018-08-18 19:04:18',
#   'Likes': 0,
#   'Retweets': 3},
#  {'Tweets': 'RT @mr2amc: Our paper submission system is ready on EasyChair for @mr2amc \n\nhttps://t.co/kMfbLOcz6x\n\nYou may submit your original contribut…',
#   'Len': 140,
#   'Date Time': '2018-08-18 17:19:21',
#   'Likes': 0,
#   'Retweets': 3},
#  {'Tweets': 'RT @NurtureAI: How do you choose the hyperparameters of an NN model? While current methods revolve around trial and error, this becomes inf…',
#   'Len': 140,
#   'Date Time': '2018-08-18 03:55:34',
#   'Likes': 0,
#   'Retweets': 5},
#  {'Tweets': 'RT @kdnuggets: Diving Deep into Deepfakes https://t.co/gM5xM4pMkz https://t.co/o969Jpeuwr',
#   'Len': 89,
#   'Date Time': '2018-08-16 06:13:04',
#   'Likes': 0,
#   'Retweets': 12},
#  {'Tweets': 'Congratulations @midasIIITD @IIITDelhi interns, Deepanshu, Meghna, and Ashutosh for getting their paper accepted to… https://t.co/WyswsIkPoh',
#   'Len': 140,
#   'Date Time': '2018-08-16 04:30:12',
#   'Likes': 7,
#   'Retweets': 3},
#  {'Tweets': 'RT @jain49: This is magic. In fact, more than magic, real transformation. https://t.co/tQbbb8Ka36',
#   'Len': 97,
#   'Date Time': '2018-08-15 14:38:37',
#   'Likes': 0,
#   'Retweets': 1},
#  {'Tweets': 'RT @kdnuggets: The Best Metric to Measure Accuracy of Classification Models #KDN https://t.co/RBFTGnKr5M',
#   'Len': 104,
#   'Date Time': '2018-08-15 14:37:22',
#   'Likes': 0,
#   'Retweets': 6},
#  {'Tweets': 'RT @kdnuggets: KDnuggets 18:n31: Top 10 roles in #AI and #datascience; Github Data Science Spotlight: #Python tools for #MachineLearning ht…',
#   'Len': 140,
#   'Date Time': '2018-08-15 14:36:08',
#   'Likes': 0,
#   'Retweets': 6},
#  {'Tweets': 'RT @ponguru: Looking for ideas / projects in #privacy and #security in #socialnetwork? Here is a list of ideas that you can explore https:/…',
#   'Len': 140,
#   'Date Time': '2018-08-15 09:03:25',
#   'Likes': 0,
#   'Retweets': 4},
#  {'Tweets': 'RT @coling2018: #COLING2018 proceedings are now in the ACL Anthology! https://t.co/75kJ0btl3M\n\n#nlproc #linguistics Check out those multili…',
#   'Len': 140,
#   'Date Time': '2018-08-13 10:48:07',
#   'Likes': 0,
#   'Retweets': 28},
#  {'Tweets': 'Very interesting! We at @midasIIITD, also doing some work on @DigitalHealth. Hope to present them in upcoming confe… https://t.co/WRBWaYRCup',
#   'Len': 140,
#   'Date Time': '2018-08-12 15:07:30',
#   'Likes': 3,
#   'Retweets': 1},
#  {'Tweets': 'RT @kdnuggets: GitHub Python Data Science Spotlight: AutoML, NLP, Visualization, ML Workflows https://t.co/83nUhUzxF6 https://t.co/213EnP8x…',
#   'Len': 140,
#   'Date Time': '2018-08-12 14:19:37',
#   'Likes': 0,
#   'Retweets': 45},
#  {'Tweets': 'RT @mr2amc: @mr2amc will be organized by Prof @RatnRajiv and A V Subramanyam (@IIITDelhi ), Prof Roger Zimmermann and Yifang Yin (@NUSCompu…',
#   'Len': 140,
#   'Date Time': '2018-08-12 13:11:04',
#   'Likes': 0,
#   'Retweets': 2},
#  {'Tweets': 'RT @mr2amc: Our workshop proposal on Multimodal Representation, Retrieval, and Analysis of Multimedia Content in Social Media (MR2AMC) http…',
#   'Len': 140,
#   'Date Time': '2018-08-12 09:07:16',
#   'Likes': 0,
#   'Retweets': 2},
#  {'Tweets': "NLP's ImageNet moment has arrived » https://t.co/miZDIXKpq5 #natural language processing #nlp #transfer learning",
#   'Len': 112,
#   'Date Time': '2018-08-12 04:29:38',
#   'Likes': 2,
#   'Retweets': 0},
#  {'Tweets': '@soujanyaporia @nlp Congrats Dr. @soujanyaporia',
#   'Len': 47,
#   'Date Time': '2018-08-11 08:48:40',
#   'Likes': 1,
#   'Retweets': 0},
#  {'Tweets': 'RT @kdnuggets: Ultimate Guide to Getting Started with Tensorflow https://t.co/tWpYBsmbG5 https://t.co/jXi4GK97mX',
#   'Len': 112,
#   'Date Time': '2018-08-09 10:17:53',
#   'Likes': 0,
#   'Retweets': 111},
#  {'Tweets': 'RT @TensorFlow: TensorFlow 1.10.0 has been released! Please see the full release notes for details on added features and changes ↓ https://…',
#   'Len': 140,
#   'Date Time': '2018-08-09 05:59:57',
#   'Likes': 0,
#   'Retweets': 265},
#  {'Tweets': '@midasIIITD is looking for motivated IIITD MTech students who have an interest in research and deep learning techni… https://t.co/jxUuuTNO8A',
#   'Len': 140,
#   'Date Time': '2018-08-08 11:30:56',
#   'Likes': 2,
#   'Retweets': 1},
#  {'Tweets': '@IIITDelhi @ponguru @RatnRajiv The results of @midasIIITD are as follows https://t.co/I8bOPaJSQv',
#   'Len': 96,
#   'Date Time': '2018-08-08 05:53:48',
#   'Likes': 3,
#   'Retweets': 1},
#  {'Tweets': 'RT @IIITDelhi: @midasIIITD has secured rank 1 in the IRMiDis challenge of the 10th FIRE 2018 conference. Congratulations MIDAS interns, Sak…',
#   'Len': 140,
#   'Date Time': '2018-08-08 05:45:58',
#   'Likes': 0,
#   'Retweets': 1},
#  {'Tweets': 'RT @kdnuggets: Comparison of Top 6 Python NLP Libraries https://t.co/3ubomIUh4N https://t.co/KgP6R9mZsD',
#   'Len': 103,
#   'Date Time': '2018-08-07 07:16:33',
#   'Likes': 0,
#   'Retweets': 40},
#  {'Tweets': 'Check more details of the 20th IEEE International Symposium on Multimedia (ISM) conference at… https://t.co/6NL6nhWrXI',
#   'Len': 118,
#   'Date Time': '2018-08-07 02:05:12',
#   'Likes': 1,
#   'Retweets': 1},
#  {'Tweets': 'MR2AMC@ISM 2018 will be organized by @RatnRajiv (@midasIIITD), @debanjanbhucs (@TechAtBloomberg), Yifang Yin (… https://t.co/6gXWHEG0TC',
#   'Len': 135,
#   'Date Time': '2018-08-07 01:58:49',
#   'Likes': 1,
#   'Retweets': 1},
#  {'Tweets': 'Our workshop proposal named, "MR2AMC: Multimodal Representation,\nRetrieval, and Analysis of Multimedia Content in S… https://t.co/NdY84xlAiJ',
#   'Len': 140,
#   'Date Time': '2018-08-07 01:50:33',
#   'Likes': 1,
#   'Retweets': 1},
#  {'Tweets': '@NUSComputing Congratulations Abdelhak and Prof Zimmermann.',
#   'Len': 59,
#   'Date Time': '2018-08-06 17:48:23',
#   'Likes': 0,
#   'Retweets': 0},
#  {'Tweets': 'RT @goodfellow_ian: One of the most anticipated GAN names now taken: paGAN. https://t.co/ifUgy40O8t https://t.co/NvxKDwEMZz',
#   'Len': 123,
#   'Date Time': '2018-08-06 17:46:59',
#   'Likes': 0,
#   'Retweets': 103},
#  {'Tweets': '@the_dhumketu Great to have you in @midasIIITD',
#   'Len': 46,
#   'Date Time': '2018-08-06 06:06:47',
#   'Likes': 0,
#   'Retweets': 0},
#  {'Tweets': 'Congratulation @soujanyaporia for being appointed as an Adjunct Faculty of @IIITDelhi. He will be working with team… https://t.co/Rve8ewvi4I',
#   'Len': 140,
#   'Date Time': '2018-08-03 05:56:33',
#   'Likes': 6,
#   'Retweets': 1},
#  {'Tweets': '@IIITDelhi @the_dhumketu Thanks team @midasIIITD https://t.co/2WvhaHBq3h',
#   'Len': 72,
#   'Date Time': '2018-08-01 11:47:15',
#   'Likes': 5,
#   'Retweets': 1},
#  {'Tweets': 'RT @IIITDelhi: Congratulations @midasIIITD intern @the_dhumketu for getting his paper titled,"Harnessing AI for Speech Reconstruction using…',
#   'Len': 140,
#   'Date Time': '2018-08-01 11:20:07',
#   'Likes': 0,
#   'Retweets': 4},
#  {'Tweets': 'RT @learning_pt: Profile of the 5 Indian undergrads admitted to MIT for 2018-2022 session. \nNote, how they grabbed the Linguistics Olympiad…',
#   'Len': 140,
#   'Date Time': '2018-08-01 05:06:47',
#   'Likes': 0,
#   'Retweets': 4},
#  {'Tweets': 'Have a look at the list of accepted papers in ACM Multimedia 2018 if you are willing to work on some interesting mu… https://t.co/N7Biw32JS2',
#   'Len': 140,
#   'Date Time': '2018-07-31 12:11:52',
#   'Likes': 1,
#   'Retweets': 0},
#  {'Tweets': 'RT @goodfellow_ian: https://t.co/hYiWI7ntyk TensorFuzz automates the process of finding inputs that cause some specific testable behavior,…',
#   'Len': 139,
#   'Date Time': '2018-07-31 02:06:26',
#   'Likes': 0,
#   'Retweets': 264},
#  {'Tweets': 'RT @IIITDelhi: Congratulations Dr. @RatnRajiv and team @midasIIITD for getting their paper titled,"Learning and Fusing Multimodal Deep Feat…',
#   'Len': 140,
#   'Date Time': '2018-07-30 07:30:51',
#   'Likes': 0,
#   'Retweets': 2},
#  {'Tweets': 'RT @ylecun: Jitendra Malik, who directs FAIR-Menlo Park, talks about the future of computer vision in his acceptance talk after receiving t…',
#   'Len': 140,
#   'Date Time': '2018-07-28 11:07:11',
#   'Likes': 0,
#   'Retweets': 57},
#  {'Tweets': 'RT @kdnuggets: .@Bloomberg launches free course  "Foundations of #MachineLearning" for those with Strong #Math Backgrounds  https://t.co/9R…',
#   'Len': 140,
#   'Date Time': '2018-07-28 06:14:09',
#   'Likes': 0,
#   'Retweets': 105},
#  {'Tweets': 'RT @TechAtBloomberg: Missed #PyLondinium18? Watch the videos of the keynotes and other speakers now: https://t.co/ZdsCV6csy7',
#   'Len': 124,
#   'Date Time': '2018-07-28 06:13:48',
#   'Likes': 0,
#   'Retweets': 7},
#  {'Tweets': 'RT @IIITDelhi: We are delighted to announce that @IIITDelhi has joined hands with University at Buffalo, the State University of New York f…',
#   'Len': 140,
#   'Date Time': '2018-07-28 04:08:21',
#   'Likes': 0,
#   'Retweets': 6},
#  {'Tweets': "Get ready for the annual technical fest of @IIITDelhi, Esya, on 17th and 18th August 2018. The theme for this year'… https://t.co/sXbZ4j5SAN",
#   'Len': 140,
#   'Date Time': '2018-07-27 06:46:44',
#   'Likes': 3,
#   'Retweets': 2},
#  {'Tweets': 'Congratulations Dr. @RatnRajiv and team @midasIIITD for getting their paper titled,"Learning and Fusing Multimodal… https://t.co/HWZ1aqzERE',
#   'Len': 139,
#   'Date Time': '2018-07-27 04:07:31',
#   'Likes': 8,
#   'Retweets': 2},
#  {'Tweets': 'Congratulations MIDAS @midasIIITD intern Prakhar Srivastava @prakharcode for being selected to give a talk in PyCon… https://t.co/b1cUb4VMss',
#   'Len': 140,
#   'Date Time': '2018-07-25 05:14:35',
#   'Likes': 5,
#   'Retweets': 1},
#  {'Tweets': 'MIDAS@IIITD foundation. https://t.co/LKuzyBHzjm',
#   'Len': 47,
#   'Date Time': '2018-07-24 10:33:23',
#   'Likes': 2,
#   'Retweets': 1},
#  {'Tweets': 'It feels great to be the part of @IIITDelhi. https://t.co/IRRTtIpC6D',
#   'Len': 68,
#   'Date Time': '2018-07-24 10:12:34',
#   'Likes': 2,
#   'Retweets': 1},
#  {'Tweets': 'Thank you, @toonzratn for designing the logo of MIDAS. https://t.co/yx2u2Vs36Z',
#   'Len': 78,
#   'Date Time': '2018-07-24 09:46:26',
#   'Likes': 4,
#   'Retweets': 1},
#  {'Tweets': 'We are on Facebook too. Like our page to get our updates. https://t.co/CRaw6KQPSf\n\n#MIDAS #IIITD… https://t.co/0gj73NnlGc',
#   'Len': 121,
#   'Date Time': '2018-07-23 16:25:05',
#   'Likes': 3,
#   'Retweets': 1},
#  {'Tweets': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for societ… https://t.co/omKEqF7xqN',
#   'Len': 140,
#   'Date Time': '2018-07-23 12:53:15',
#   'Likes': 7,
#   'Retweets': 4}]

# %% [markdown]
# Converting Json data to DataFrame

# %%
tweets = pd.DataFrame.from_dict(data)
print(tweets)
# Out:
#                Date Time  Len  Likes  Retweets  \
# 0    2019-04-10 09:01:29  139      0         0
# 1    2019-04-10 04:51:26  139      0         1
# 2    2019-04-09 16:45:07  140      0        14
# 3    2019-04-09 05:04:27  136      0        35
# 4    2019-04-09 05:04:11  140      0        17
# 5    2019-04-08 19:38:09  140      0        15
# 6    2019-04-08 07:08:12  140     18         2
# 7    2019-04-08 03:27:42  140      5         0
# 8    2019-04-07 14:17:29   55      0         0
# 9    2019-04-07 14:17:09   50      0         0
# 10   2019-04-07 11:43:24  140      1         1
# 11   2019-04-07 06:55:19  139      5         2
# 12   2019-04-07 06:53:38  140      4         1
# 13   2019-04-07 05:32:27  140      6         1
# 14   2019-04-07 05:29:40  140      7         1
# 15   2019-04-06 17:11:29   89      0         2
# 16   2019-04-06 16:43:27  140     18         3
# 17   2019-04-05 16:08:37  140     11         1
# 18   2019-04-05 04:05:11  139      0        16
# 19   2019-04-05 04:04:43   98      0        11
# 20   2019-04-03 18:31:53  140      0        59
# 21   2019-04-03 17:04:32  140      0       872
# 22   2019-04-03 09:03:40  113      0        16
# 23   2019-04-03 07:46:02  140      0         4
# 24   2019-04-02 04:20:13  140      8         1
# 25   2019-04-02 02:44:54  140      5         1
# 26   2019-04-02 02:35:44  140      0         7
# 27   2019-04-01 06:53:08  140      7         2
# 28   2019-03-31 10:21:24  140      0        10
# 29   2019-03-29 19:43:24  140      0         2
# ..                   ...  ...    ...       ...
# 314  2018-08-09 05:59:57  140      0       265
# 315  2018-08-08 11:30:56  140      2         1
# 316  2018-08-08 05:53:48   96      3         1
# 317  2018-08-08 05:45:58  140      0         1
# 318  2018-08-07 07:16:33  103      0        40
# 319  2018-08-07 02:05:12  118      1         1
# 320  2018-08-07 01:58:49  135      1         1
# 321  2018-08-07 01:50:33  140      1         1
# 322  2018-08-06 17:48:23   59      0         0
# 323  2018-08-06 17:46:59  123      0       103
# 324  2018-08-06 06:06:47   46      0         0
# 325  2018-08-03 05:56:33  140      6         1
# 326  2018-08-01 11:47:15   72      5         1
# 327  2018-08-01 11:20:07  140      0         4
# 328  2018-08-01 05:06:47  140      0         4
# 329  2018-07-31 12:11:52  140      1         0
# 330  2018-07-31 02:06:26  139      0       264
# 331  2018-07-30 07:30:51  140      0         2
# 332  2018-07-28 11:07:11  140      0        57
# 333  2018-07-28 06:14:09  140      0       105
# 334  2018-07-28 06:13:48  124      0         7
# 335  2018-07-28 04:08:21  140      0         6
# 336  2018-07-27 06:46:44  140      3         2
# 337  2018-07-27 04:07:31  139      8         2
# 338  2018-07-25 05:14:35  140      5         1
# 339  2018-07-24 10:33:23   47      2         1
# 340  2018-07-24 10:12:34   68      2         1
# 341  2018-07-24 09:46:26   78      4         1
# 342  2018-07-23 16:25:05  121      3         1
# 343  2018-07-23 12:53:15  140      7         4
#
#                                                 Tweets
# 0    Clarification: Our earlier post which indicate...
# 1    RT @IIITDelhi: Applications open for MTech (CB...
# 2    RT @IIITDelhi: We are delighted to share that ...
# 3    RT @Harvard: Professor Jelani Nelson founded A...
# 4    RT @emnlp2019: For anyone interested in submit...
# 5    RT @multimediaeval: Announcing the 2019 MediaE...
# 6    Many Congratulations to @midasIIITD student, S...
# 7    @midasIIITD thanks all students who have appea...
# 8    @himanchalchandr Meanwhile, complete CV/NLP ta...
# 9    @sayangdipto123 Submit as per the guideline ag...
# 10   We request all students whose interview are sc...
# 11   Other queries: "none of the Tweeter Apis give ...
# 12   Other queries: "do we have to make two differe...
# 13   Other queries: "If using Twitter api, it does ...
# 14   Response to some queries asked by students on ...
# 15   RT @kdnuggets: Top 8 #Free Must-Read #Books on...
# 16   @nupur_baghel @PennDATS Congratulation @nupur_...
# 17   We have emailed the task details to all candid...
# 18   RT @rfpvjr: Our NAACL paper on polarization in...
# 19   RT @kdnuggets: Effective Transfer Learning For...
# 20   RT @stanfordnlp: What’s new in @Stanford CS224...
# 21   RT @DeepMindAI: Today we're releasing a large-...
# 22   RT @ylecun: Congratulations Jitendra Malik !\n...
# 23   RT @IIITDelhi: Another chance to take admissio...
# 24   Dear @midasIIITD internship candidates who hav...
# 25   Looking forward to your paper submission to @I...
# 26   RT @ngrams: Reproducibility in multimedia rese...
# 27   Online application for https://t.co/DJFDrQsHZP...
# 28   RT @ACMMM19: A final reminder of the Reproduci...
# 29   RT @isarth23: Thanks for the support and help ...
# ..                                                 ...
# 314  RT @TensorFlow: TensorFlow 1.10.0 has been rel...
# 315  @midasIIITD is looking for motivated IIITD MTe...
# 316  @IIITDelhi @ponguru @RatnRajiv The results of ...
# 317  RT @IIITDelhi: @midasIIITD has secured rank 1 ...
# 318  RT @kdnuggets: Comparison of Top 6 Python NLP ...
# 319  Check more details of the 20th IEEE Internatio...
# 320  MR2AMC@ISM 2018 will be organized by @RatnRaji...
# 321  Our workshop proposal named, "MR2AMC: Multimod...
# 322  @NUSComputing Congratulations Abdelhak and Pro...
# 323  RT @goodfellow_ian: One of the most anticipate...
# 324     @the_dhumketu Great to have you in @midasIIITD
# 325  Congratulation @soujanyaporia for being appoin...
# 326  @IIITDelhi @the_dhumketu Thanks team @midasIII...
# 327  RT @IIITDelhi: Congratulations @midasIIITD int...
# 328  RT @learning_pt: Profile of the 5 Indian under...
# 329  Have a look at the list of accepted papers in ...
# 330  RT @goodfellow_ian: https://t.co/hYiWI7ntyk Te...
# 331  RT @IIITDelhi: Congratulations Dr. @RatnRajiv ...
# 332  RT @ylecun: Jitendra Malik, who directs FAIR-M...
# 333  RT @kdnuggets: .@Bloomberg launches free cours...
# 334  RT @TechAtBloomberg: Missed #PyLondinium18? Wa...
# 335  RT @IIITDelhi: We are delighted to announce th...
# 336  Get ready for the annual technical fest of @II...
# 337  Congratulations Dr. @RatnRajiv and team @midas...
# 338  Congratulations MIDAS @midasIIITD intern Prakh...
# 339    MIDAS@IIITD foundation. https://t.co/LKuzyBHzjm
# 340  It feels great to be the part of @IIITDelhi. h...
# 341  Thank you, @toonzratn for designing the logo o...
# 342  We are on Facebook too. Like our page to get o...
# 343  MIDAS is a group of researchers at IIIT-Delhi ...
#
# [344 rows x 5 columns]
